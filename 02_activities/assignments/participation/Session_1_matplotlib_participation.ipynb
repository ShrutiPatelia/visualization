# %%
# Making a basic figure with matplotlip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (2.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Adding axis labels and titles

# %%
ax.set_title('Total growth over time')
ax.set_ylabel('Total grownt')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
# modifying labels and  titles
font1 = {'family' :'sans-serif', 'color' :'blue', 'size' :20}
font2 = {'family' :'monospace', 'color' :'green', 'size' :14}

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
# Moving labels and titles

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc = 'left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
# Modifying data points
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x,
           y,
           marker='*',  # New additions
           color = "indigo") #New additions
fig.show()
# Out:
# /var/folders/rh/l65fvwtx5nj5x7xz9tv_3_vw0000gn/T/ipykernel_14028/1262810081.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Modifying data points
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x,
           y,
           marker='*', 
           color = "indigo",
           linestyle = "--", #New additions
           linewidth = 2)

fig.show()
# Out:
# /var/folders/rh/l65fvwtx5nj5x7xz9tv_3_vw0000gn/T/ipykernel_14028/3453448037.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Modifying data points: colour
fig, ax = plt.subplots(figsize=(5, 3))

# color being the new addition

ax.plot( x, y, marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
fig.show()
# Out:
# /var/folders/rh/l65fvwtx5nj5x7xz9tv_3_vw0000gn/T/ipykernel_14028/2948829041.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Modifying further
ax.plot(x,y,marker='*',
        markersize = 12, # new additions
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359', # new additions
        markerfacecolor = '#fa9359') # new additions

# %%
ax.grid(axis = 'y')

# %%
ax.grid(axis = 'y', color = "blue", linewidth = 2, linestyle = '-.')

# %%
# activity

# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# create data
df = pd.DataFrame({
      'x': np.random.rand(40),
      'y': np.random.rand(40),
      'z': np.random.rand(40),
   })
df.head()
# Out:
#           x         y         z
# 0  0.209763  0.034343  0.331647
# 1  0.872210  0.752728  0.779469
# 2  0.042777  0.795411  0.834174
# 3  0.106636  0.973569  0.069892
# 4  0.945267  0.258043  0.998580

# %%
plt.scatter(df['x'], df['y'], s=df['z']*1000, alpha=0.5)
plt.show()

# %%
# Change color
plt.scatter(df['x'], df['y'], s=df['z']*1000, c="green", alpha=0.4)

# show the graph
plt.show()

# %%
# plot
plt.scatter(df['x'], df['y'], s=df['z']*1000, c="green", alpha=0.4, linewidth=6)

# show the graph
plt.show()
